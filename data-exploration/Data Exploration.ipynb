# %%
import pandas as pd

# %%
df=pd.read_parquet('../data/input_dataset-2.parquet')

# %%
df.head()
# Out:
#                      Unit_4_Power  Unit_4_Reactive Power  \
# timepoints
# 1970-12-19 09:51:44    262.204308               2.899036
# 1970-12-19 09:51:45    262.104319               3.344630
# 1970-12-19 09:51:46    262.004330               3.790223
# 1970-12-19 09:51:47    261.904340               4.235817
# 1970-12-19 09:51:48    261.804351               4.064759
#
#                      Turbine_Guide Vane Opening  Turbine_Pressure Drafttube  \
# timepoints
# 1970-12-19 09:51:44                   82.279976                  173.955216
# 1970-12-19 09:51:45                   82.277248                  173.989815
# 1970-12-19 09:51:46                   82.274520                  174.024413
# 1970-12-19 09:51:47                   82.271792                  174.059012
# 1970-12-19 09:51:48                   82.269064                  174.153819
#
#                      Turbine_Pressure Spiral Casing  Turbine_Rotational Speed  \
# timepoints
# ...

# %%
import matplotlib.pyplot as plt
tmp = df.resample('1T').mean().filter(regex='Tensile')

(tmp/tmp.mean()).plot(figsize=(15,5))
plt.ylabel('Tensile divided by its mean')
# Out:
# Text(0, 0.5, 'Tensile divided by its mean')

# %%
# Check correlations
df.corr()
# Out:
#                                 Unit_4_Power  Unit_4_Reactive Power  \
# Unit_4_Power                        1.000000               0.532486
# Unit_4_Reactive Power               0.532486               1.000000
# Turbine_Guide Vane Opening          0.996978               0.524250
# Turbine_Pressure Drafttube         -0.943016              -0.556985
# Turbine_Pressure Spiral Casing     -0.821427              -0.553477
# Turbine_Rotational Speed            0.289999               0.032015
# Bolt_1_Steel tmp                    0.043520               0.127236
# Bolt_1_Tensile                      0.068859              -0.127559
# Bolt_2_Tensile                      0.153266              -0.078259
# Bolt_3_Tensile                      0.111489              -0.066875
# Bolt_4_Tensile                      0.696221               0.294615
# Bolt_5_Tensile                      0.663551               0.281187
# Bolt_6_Tensile                      0.321165               0.025609
# ...

# %%
df.columns
# Out:
# Index(['Unit_4_Power', 'Unit_4_Reactive Power', 'Turbine_Guide Vane Opening',
#        'Turbine_Pressure Drafttube', 'Turbine_Pressure Spiral Casing',
#        'Turbine_Rotational Speed', 'mode', 'Bolt_1_Steel tmp',
#        'Bolt_1_Tensile', 'Bolt_2_Tensile', 'Bolt_3_Tensile', 'Bolt_4_Tensile',
#        'Bolt_5_Tensile', 'Bolt_6_Tensile', 'Bolt_1_Torsion', 'Bolt_2_Torsion',
#        'Bolt_3_Torsion', 'Bolt_4_Torsion', 'Bolt_5_Torsion', 'Bolt_6_Torsion',
#        'lower_bearing_vib_vrt', 'turbine_bearing_vib_vrt'],
#       dtype='object')

# %%
df[['Unit_4_Power', 'Unit_4_Reactive Power', 'Turbine_Guide Vane Opening',
       'Turbine_Pressure Drafttube', 'Turbine_Pressure Spiral Casing',
       'Turbine_Rotational Speed']].plot(figsize=(15,15), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='timepoints'>,
#        <AxesSubplot:xlabel='timepoints'>,
#        <AxesSubplot:xlabel='timepoints'>,
#        <AxesSubplot:xlabel='timepoints'>,
#        <AxesSubplot:xlabel='timepoints'>,
#        <AxesSubplot:xlabel='timepoints'>], dtype=object)
